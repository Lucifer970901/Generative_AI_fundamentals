# %%
from transformers import pipeline

# %%
text = "Python is a high level, general-purpose programming language."
pipe = pipeline("text-to-speech",model = "suno/bark-small",device = 'cuda') 
output = pipe(text)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/353 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cuda
# ...

# %%
output
# Out:
# {'audio': array([[0.00083876, 0.00025216, 0.0003029 , ..., 0.00027936, 0.00030179,
#          0.00030726]], dtype=float32),
#  'sampling_rate': 24000}

# %%
from IPython.display import Audio
Audio(output['audio'],rate = output['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# if you want to use supertone/supersonic model locally (as it is optimized for cpu)
# * install git lfs
# * clone the following directories
# * install packages in Requirements.txt
# * run the sample, 'example_onnx.py'

# %%
# !git clone https://github.com/supertone-inc/supertonic.git
# !cd supertonic
# !git clone https://huggingface.co/Supertone/supertonic assets
# Out:
# Cloning into 'supertonic'...
# Cloning into 'assets'...
# Updating files:  43% (7/16)
# Updating files:  50% (8/16)
# Updating files:  56% (9/16)
# Updating files:  62% (10/16)
# Updating files:  68% (11/16)
# Updating files:  75% (12/16)
# Updating files:  81% (13/16)
# Updating files:  87% (14/16)
# Updating files:  93% (15/16)
# Updating files: 100% (16/16)
# Updating files: 100% (16/16), done.
# Filtering content:  50% (2/4)
# Filtering content:  75% (3/4), 27.51 MiB | 3.55 MiB/s
# Filtering content: 100% (4/4), 153.85 MiB | 6.69 MiB/s
# Filtering content: 100% (4/4), 250.55 MiB | 9.28 MiB/s, done.

# %%
import os

target_dir = 'supertonic/py'

# 1. Change Directory (Pure Python - NO !)
# This is the essential fix. It changes the directory for the Jupyter kernel.
try:
    os.chdir(target_dir)
    print("Successfully changed directory to:", os.getcwd())
except FileNotFoundError:
    print(f"Error: Directory '{target_dir}' not found.")
    # Stop here if the directory doesn't exist

# --- Shell Commands (Prefixed with !) ---

# Note: We use .\venv\Scripts\ for common Windows compatibility.
# If you are on Linux/macOS, you must use ./venv/bin/

# 2. Create the virtual environment named 'venv'
# !python -m venv venv

# 3. Install ipykernel into the NEW virtual environment
# !.\venv\Scripts\pip install ipykernel

# 4. Register the new venv as a Jupyter kernel
# !.\venv\Scripts\python -m ipykernel install --user --name=supertonic_env --display-name="Supertonic (venv)"

# 5. Install requirements.txt into the NEW virtual environment
# !.\venv\Scripts\pip install -r requirements.txt
# Out:
# Successfully changed directory to: c:\Users\megha\Documents\Git_repo_folders\Gen_AI_fundamentals\Projects\supertonic\py
# ...
#   Using cached ipykernel-7.1.0-py3-none-any.whl (117 kB)
# ...
#   Using cached jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# ...
#   Using cached matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# ...
#   Using cached ipython-8.37.0-py3-none-any.whl (831 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# ...
#   Using cached debugpy-1.8.17-cp310-cp310-win_amd64.whl (5.3 MB)
# ...
#   Using cached comm-0.2.3-py3-none-any.whl (7.3 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# ...
#   Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# ...
#   Using cached psutil-7.1.3-cp37-abi3-win_amd64.whl (247 kB)
# ...
#   Using cached tornado-6.5.2-cp39-abi3-win_amd64.whl (445 kB)
# ...
#   Using cached pyzmq-27.1.0-cp310-cp310-win_amd64.whl (632 kB)
# ...
#   Using cached jupyter_client-8.7.0-py3-none-any.whl (106 kB)
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# ...

# %%
# !python example_onnx.py
# Out:
# Traceback (most recent call last):
#   File "c:\Users\megha\Documents\Git_repo_folders\Gen_AI_fundamentals\Projects\supertonic\py\example_onnx.py", line 4, in <module>
#     import soundfile as sf
# ModuleNotFoundError: No module named 'soundfile'
