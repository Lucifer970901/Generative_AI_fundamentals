# %%
import pandas as pd
datapath = "../Datasets/twitter_dataset/twitter_training.csv"
df = pd.read_csv(datapath)
df.shape
# Out:
# (74681, 4)

# %%
df = df.head(1000) #selecting only first 1000 rows
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.columns = ['tweet_id','entity','sentiment','tweet_content']

# %%
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df['tweet_content'][7]
# Out:
# "So I spent a few hours doing something for fun... If you don't know I'm a HUGE @ Borderlands fan and Maya is one of my favorite characters."

# %%
df.isnull().sum() #finding the number of null values
# Out:
# tweet_id         0
# entity           0
# sentiment        0
# tweet_content    4
# dtype: int64

# %%
df.dropna(inplace = True) #drop null values

# %%
df.duplicated().sum() #sum of duplicate values
# Out:
# np.int64(31)

# %%
# Identify the duplicate rows (keeping all copies)
duplicate_rows = df[df.duplicated(keep=False)]

# Display the columns that are duplicating the content
print(duplicate_rows[['tweet_id', 'tweet_content']].sort_values(by='tweet_content'))
# Out:
#      tweet_id                                      tweet_content
# 143      2425                                    "What a bitch!"
# 145      2425                                    "What a bitch!"
# 515      2489  . :: Ah yes. A very very old image of demon Lo...
# 518      2489  . :: Ah yes. A very very old image of demon Lo...
# 61       2411                                               .. [
# 63       2411                                               .. [
# 592      2503                                             ......
# 591      2503                                             ......
# 623      2509  4 player local Borderlands 3. Such a great wee...
# 624      2509  4 player local Borderlands 3. Such a great wee...
# 689      2522  A Noob Trys To Make A Salvador Build Borderlan...
# 692      2522  A Noob Trys To Make A Salvador Build Borderlan...
# 967      2572                            AGAIN @ Borderlands WTF
# 966      2572                            AGAIN @ Borderlands WTF
# 702      2524  Beat DLC2 main story line. Loved it! Thank you...
# 703      2524  Beat DLC2 main story line. Loved it! Thank you...
# 167      2429  Bioshock AND borderlands coming to the switch ...
# 168      2429  Bioshock AND borderlands coming to the switch ...
# 50       2409  Blaming Sight for Tardiness! A little bit of b...
# 47       2409  Blaming Sight for Tardiness! A little bit of b...
# 203      2435                       Borderlands 2 is so good omg
# 204      2435                       Borderlands 2 is so good omg
# 205      2435                       Borderlands 2 is so good omg
# 842      2548  Borderlands 3 Update Delayed Due To Anti-Racis...
# 839      2548  Borderlands 3 Update Delayed Due To Anti-Racis...
# 239      2441  Borderlands 3 is good so far but Borderlands 2...
# 241      2441  Borderlands 3 is good so far but Borderlands 2...
# 482      2481  Have u played borderlands 3? Pretty fun imo. A...
# 479      2481  Have u played borderlands 3? Pretty fun imo. A...
# 875      2555                    Holy shit borderlands 3 is ass.
# 877      2555                    Holy shit borderlands 3 is ass.
# 306      2452                              I hate this algorithm
# 305      2452                              I hate this algorithm
# 833      2547                                      I love u guys
# 835      2547                                      I love u guys
# 185      2432  Jumping on stream early today! Playing some mo...
# 188      2432  Jumping on stream early today! Playing some mo...
# 461      2478  Lil preview of a Maya drawing I've been chippi...
# 464      2478  Lil preview of a Maya drawing I've been chippi...
# 884      2556  Live with some super interesting *LOL* boss fa...
# 881      2556  Live with some super interesting *LOL* boss fa...
# 959      2571  Mayhem and Murder Aplenty! It's time for a  . ...
# 962      2571  Mayhem and Murder Aplenty! It's time for a  . ...
# 650      2515  Morning~!!. I'm split on playing PSO2 or Borde...
# 647      2515  Morning~!!. I'm split on playing PSO2 or Borde...
# 989      2576                                              Sweet
# 992      2576                                              Sweet
# 990      2576                                              Sweet
# 25       2405  The biggest disappointment of my life came a y...
# 24       2405  The biggest disappointment of my life came a y...
# 350      2459  best borderlands character :y pic.twitter.com/...
# 347      2459  best borderlands character :y pic.twitter.com/...
# 200      2434              fuck it .  pic.twitter.com/Wav1bacr5j
# 197      2434              fuck it .  pic.twitter.com/Wav1bacr5j
# 193      2433    i enter that gunner seat and i fear for my life
# 191      2433    i enter that gunner seat and i fear for my life
# 713      2526  me: omg I miss Rhys soooo much I would do anyt...
# 716      2526  me: omg I miss Rhys soooo much I would do anyt...
# 19       2404  that was the first borderlands session in a lo...
# 17       2404  that was the first borderlands session in a lo...

# %%
df = df.drop_duplicates(subset=['tweet_content'], keep='first') #drop the duplicates
print(df.duplicated().sum()) #0 means no duplicate values
print(df.dropna().count()) #returns the count of unique values
# Out:
# 0
# tweet_id         959
# entity           959
# sentiment        959
# tweet_content    959
# dtype: int64

# %% [markdown]
# now there is unique set of 959 rows on which we can perform some preprocessing operation

# %% [markdown]
# **Converting to lower case**

# %%
df['tweet_content'] = df["tweet_content"].str.lower()

# %%
df['tweet_content'][7]
# Out:
# "so i spent a few hours doing something for fun... if you don't know i'm a huge @ borderlands fan and maya is one of my favorite characters."

# %% [markdown]
# remove html tags

# %%
import re
def remove_html_tags(text):
    pattern = re.compile("<.*?>")
    return pattern.sub(r" ",text)

# %%
df['tweet_content'] = df["tweet_content"].apply(remove_html_tags)

# %%
df['tweet_content'][7]
# Out:
# "so i spent a few hours doing something for fun... if you don't know i'm a huge @ borderlands fan and maya is one of my favorite characters."

# %% [markdown]
# **Remove URL**

# %%
def remove_url(text):
    pattern = re.compile(r"https?://\S+|www\.\S+")
    return pattern.sub(r"",text)

# %%
df['tweet_content'] = df['tweet_content'].apply(remove_url)

# %%
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content
# 0  i am coming to the borders and i will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %% [markdown]
# **Remove Punctuation**

# %%
import string,time
exclude = string.punctuation
def remove_punc1(text):
    return text.translate(str.maketrans('','',exclude))

# %%
df['tweet_content'] = df['tweet_content'].apply(remove_punc1)

# %%
df['tweet_content'][7]
# Out:
# 'so i spent a few hours doing something for fun if you dont know im a huge  borderlands fan and maya is one of my favorite characters'

# %%
chat_words = {
    'AFAIK':'As Far As I Know',
    'AFK':'Away From Keyboard',
    'ASAP':'As Soon As Possible',
} 


{
    "FYI": "For Your Information",
    "ASAP": "As Soon As Possible",
    "BRB": "Be Right Back",
    "BTW": "By The Way",
    "OMG": "Oh My God",
    "IMO": "In My Opinion",
    "LOL": "Laugh Out Loud",
    "TTYL": "Talk To You Later",
    "GTG": "Got To Go",
    "TTYT": "Talk To You Tomorrow",
    "IDK": "I Don't Know",
    "TMI": "Too Much Information",
    "IMHO": "In My Humble Opinion",
    "ICYMI": "In Case You Missed It",
    "AFAIK": "As Far As I Know",
    "BTW": "By The Way",
    "FAQ": "Frequently Asked Questions",
    "TGIF": "Thank God It's Friday",
    "FYA": "For Your Action",
    "ICYMI": "In Case You Missed It",
}
# Out:
# {'FYI': 'For Your Information',
#  'ASAP': 'As Soon As Possible',
#  'BRB': 'Be Right Back',
#  'BTW': 'By The Way',
#  'OMG': 'Oh My God',
#  'IMO': 'In My Opinion',
#  'LOL': 'Laugh Out Loud',
#  'TTYL': 'Talk To You Later',
#  'GTG': 'Got To Go',
#  'TTYT': 'Talk To You Tomorrow',
#  'IDK': "I Don't Know",
#  'TMI': 'Too Much Information',
#  'IMHO': 'In My Humble Opinion',
#  'ICYMI': 'In Case You Missed It',
#  'AFAIK': 'As Far As I Know',
#  'FAQ': 'Frequently Asked Questions',
#  'TGIF': "Thank God It's Friday",
#  'FYA': 'For Your Action'}

# %% [markdown]
# **Chat conversion**

# %%
def chat_conversion(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_words:
            converted_word = chat_words[w.upper()].lower()
            new_text.append(converted_word)
        else:
            new_text.append(w)
    return " ".join(new_text)

# %%
df['tweet_content'] = df['tweet_content'].apply(chat_conversion)

# %%
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content
# 0  i am coming to the borders and i will kill you...
# 1  im getting on borderlands and i will kill you all
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %% [markdown]
# **Stopwords removal**

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\megha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
def remove_stopwords(text):
    new_text = []
    for w in text.split():
        if w in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(w)
    x = new_text[:]
    new_text.clear()
    return ' '.join(x)

# %%
df['tweet_content_stopwords']=df['tweet_content'].apply(remove_stopwords)

# %%
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content  \
# 0  i am coming to the borders and i will kill you...
# 1  im getting on borderlands and i will kill you all
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...
#
#                   tweet_content_stopwords
# 0              coming   borders    kill
# 1       im getting  borderlands    kill
# 2      im coming  borderlands    murder
# 3  im getting  borderlands 2    murder
# 4     im getting  borderlands    murder

# %% [markdown]
# **Handle Emoji's**

# %%
import emoji
def demogize_emoji(text):
    return emoji.demojize(str(text))

# %%
text = "Loved the movie. It was 😘😘"
demogize_emoji(text)
# Out:
# 'Loved the movie. It was :face_blowing_a_kiss::face_blowing_a_kiss:'

# %% [markdown]
# **Tokenization**

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\megha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
sent1 = "I am going to Jacksonville"
print(word_tokenize(sent1))
# Out:
# ['I', 'am', 'going', 'to', 'Jacksonville']

# %%
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content  \
# 0  i am coming to the borders and i will kill you...
# 1  im getting on borderlands and i will kill you all
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...
#
#                   tweet_content_stopwords
# 0              coming   borders    kill
# 1       im getting  borderlands    kill
# 2      im coming  borderlands    murder
# 3  im getting  borderlands 2    murder
# 4     im getting  borderlands    murder

# %% [markdown]
# let's use Spacy instead of NLTK for tokenization as the latter one is slower.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
def spacy_tokenize(text):
    doc = nlp(str(text)) #make sure you do not have null values before this.
    return [token.text for token in doc]

# %%
df['tokens'] = df['tweet_content'].apply(spacy_tokenize)
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content  \
# 0  i am coming to the borders and i will kill you...
# 1  im getting on borderlands and i will kill you all
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...
#
#                   tweet_content_stopwords  \
# 0              coming   borders    kill
# 1       im getting  borderlands    kill
# 2      im coming  borderlands    murder
# 3  im getting  borderlands 2    murder
# 4     im getting  borderlands    murder
#
#                                               tokens
# 0  [i, am, coming, to, the, borders, and, i, will...
# 1  [i, m, getting, on, borderlands, and, i, will,...
# 2  [i, m, coming, on, borderlands, and, i, will, ...
# 3  [i, m, getting, on, borderlands, 2, and, i, wi...
# 4  [i, m, getting, into, borderlands, and, i, can...

# %% [markdown]
# **Lemmatization**

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
def lemmatization(text):
    doc = nlp(str(text))
    return [token.lemma_.lower() for token in doc]

# %%
df['lemmatized_tokens'] = df['tweet_content'].apply(lemmatization)
df.head()
# Out:
#    tweet_id       entity sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        tweet_content  \
# 0  i am coming to the borders and i will kill you...
# 1  im getting on borderlands and i will kill you all
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...
#
#                   tweet_content_stopwords  \
# 0              coming   borders    kill
# 1       im getting  borderlands    kill
# 2      im coming  borderlands    murder
# 3  im getting  borderlands 2    murder
# 4     im getting  borderlands    murder
#
#                                               tokens  \
# 0  [i, am, coming, to, the, borders, and, i, will...
# 1  [i, m, getting, on, borderlands, and, i, will,...
# 2  [i, m, coming, on, borderlands, and, i, will, ...
# 3  [i, m, getting, on, borderlands, 2, and, i, wi...
# 4  [i, m, getting, into, borderlands, and, i, can...
#
#                                    lemmatized_tokens
# 0  [i, be, come, to, the, border, and, i, will, k...
# 1  [i, m, get, on, borderland, and, i, will, kill...
# 2  [i, m, come, on, borderland, and, i, will, mur...
# 3  [i, m, get, on, borderland, 2, and, i, will, m...
# 4  [i, m, get, into, borderland, and, i, can, mur...

# %% [markdown]
# Let's proceed with simple sentiment analysis using distilbert from hugging face.

# %%
#convert the lemmatized tokens to single string
df['final_text'] = df['lemmatized_tokens'].apply(lambda x: ' '.join(x))

# %%
# zero shot classification
from transformers import pipeline

# Load the zero-shot pipeline
zero_shot_pipeline = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli"
)

# Define your exact four labels
candidate_labels = ['Positive', 'Negative', 'Neutral', 'Irrelevant']

# Process the data
# The input must be a dictionary containing the list of texts and the labels
results = zero_shot_pipeline(
    df['final_text'].tolist(), 
    candidate_labels=candidate_labels,
    multi_label=False # Set to False for single-choice classification
)

# The output structure is different; you'd extract the 'prediction' and 'score'.
df['new_label'] = [res['labels'][0] for res in results]
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\megha\.cache\huggingface\hub\models--facebook--bart-large-mnli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Device set to use cpu
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\pt_utils.py:188, in PipelineChunkIterator.__next__(self)
#     186 try:
#     187     # Try to return next item
# --> 188     processed = next(self.subiterator)
#     189 except StopIteration:
#     190     # When a preprocess iterator ends, we can start looking at the next item
#     191     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)
#     194     # Another way to look at it, is we're basically flattening lists of lists
#     195     # into a single list, but with generators
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 15
#      11 candidate_labels = ['Positive', 'Negative', 'Neutral', 'Irrelevant']
#      13 # Process the data
#      14 # The input must be a dictionary containing the list of texts and the labels
# ---> 15 results = zero_shot_pipeline(
#      16     df['final_text'].tolist(),
#      17     candidate_labels=candidate_labels,
#      18     multi_label=False # Set to False for single-choice classification
#      19 )
#      21 # The output structure is different; you'd extract the 'prediction' and 'score'.
#      22 df['new_label'] = [res['labels'][0] for res in results]
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\zero_shot_classification.py:209, in ZeroShotClassificationPipeline.__call__(self, sequences, *args, **kwargs)
#     206 else:
#     207     raise ValueError(f"Unable to understand extra arguments {args}")
# --> 209 return super().__call__(sequences, **kwargs)
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1448, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1444 if can_use_iterator:
#    1445     final_iterator = self.get_iterator(
#    1446         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1447     )
# -> 1448     outputs = list(final_iterator)
#    1449     return outputs
#    1450 else:
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\pt_utils.py:126, in PipelineIterator.__next__(self)
#     123     return self.loader_batch_item()
#     125 # We're out of items within a batch
# --> 126 item = next(self.iterator)
#     127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\pt_utils.py:271, in PipelinePackIterator.__next__(self)
#     268             return accumulator
#     270 while not is_last:
# --> 271     processed = self.infer(next(self.iterator), **self.params)
#     272     if self.loader_batch_size is not None:
#     273         if isinstance(processed, torch.Tensor):
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py:33, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      31 for _ in possibly_batched_index:
#      32     try:
# ---> 33         data.append(next(self.dataset_iter))
#      34     except StopIteration:
#      35         self.ended = True
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\pt_utils.py:197, in PipelineChunkIterator.__next__(self)
#     189 except StopIteration:
#     190     # When a preprocess iterator ends, we can start looking at the next item
#     191     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)
#     194     # Another way to look at it, is we're basically flattening lists of lists
#     195     # into a single list, but with generators
#     196     self.subiterator = self.infer(next(self.iterator), **self.params)
# --> 197     processed = next(self.subiterator)
#     198 return processed
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\zero_shot_classification.py:212, in ZeroShotClassificationPipeline.preprocess(self, inputs, candidate_labels, hypothesis_template)
#     211 def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This example is {}."):
# --> 212     sequence_pairs, sequences = self._args_parser(inputs, candidate_labels, hypothesis_template)
#     214     for i, (candidate_label, sequence_pair) in enumerate(zip(candidate_labels, sequence_pairs)):
#     215         model_input = self._parse_and_tokenize([sequence_pair])
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\zero_shot_classification.py:27, in ZeroShotClassificationArgumentHandler.__call__(self, sequences, labels, hypothesis_template)
#      25 def __call__(self, sequences, labels, hypothesis_template):
#      26     if len(labels) == 0 or len(sequences) == 0:
# ---> 27         raise ValueError("You must include at least one label and at least one sequence.")
#      28     if hypothesis_template.format(labels[0]) == hypothesis_template:
#      29         raise ValueError(
#      30             f'The provided hypothesis_template "{hypothesis_template}" was not able to be formatted with the target labels. '
#      31             "Make sure the passed template includes formatting syntax such as {} where the label should go."
#      32         )
#
# ValueError: You must include at least one label and at least one sequence.

# %%
# this is binary classification - either positive or negative
from transformers import pipeline

# Load the model locally (one-time setup)
local_sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="cardiffnlp/twitter-roberta-base-sentiment-latest"
)

# Convert your final text column to a list
tweets_for_analysis = df['final_text'].tolist()

# Run the pipeline in one bulk operation
local_results = local_sentiment_pipeline(tweets_for_analysis)

# Extract results (same structure as API results)
df['sentiment_label'] = [res['label'] for res in local_results]
df['sentiment_score'] = [res['score'] for res in local_results]
# Out:
# Device set to use cpu

# %%
# ADD THIS LINE to see the count of positive and negative labels
print("\n--- Sentiment Distribution ---")
print(df['sentiment_label'].value_counts())
# Out:
# --- Sentiment Distribution ---
# sentiment_label
# NEGATIVE    518
# POSITIVE    441
# Name: count, dtype: int64

# %%
# let's validate with the data.
print(df['sentiment'].value_counts())
# Out:
# sentiment
# Positive      401
# Neutral       271
# Negative      185
# Irrelevant    102
# Name: count, dtype: int64

# %%
#if you want to use the hugging face api instead,
import os
import requests
import json
import time

API_URL = "https://router.huggingface.co/hf-inference/models/distilbert/distilbert-base-uncased-finetuned-sst-2-english"
HF_TOKEN = os.environ['HF_TOKEN']
headers = {
        "Authorization": f"Bearer {HF_TOKEN}",
        "Content-Type": "application/json"
    }

def check_api_status():
    payload = {"inputs": "This tweet is awesome."}
    response = requests.post(API_URL, headers=headers, json=payload, timeout=10)
    return response.status_code
      

# Run the check
check_api_status()
