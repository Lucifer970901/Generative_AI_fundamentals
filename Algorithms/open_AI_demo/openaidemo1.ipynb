# %%
print("hello")
# Out:
# hello

# %%
import os
import openai
from dotenv import load_dotenv

# %%
# !pip show openai
# Out:
# WARNING: Package(s) not found: openai

# %%
# %pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: c:\users\megha\anaconda3\envs\openaidemo\lib\site-packages
# Requires: aiohttp, requests, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
openai.api_key = OPENAI_API_KEY

# %%
openai.Model.list()['data']
# Out:
# [<Model model id=gpt-3.5-turbo at 0x1e1d7ca18a0> JSON: {
#    "id": "gpt-3.5-turbo",
#    "object": "model",
#    "created": 1677610602,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-5.1-codex-max at 0x1e1d7ca16c0> JSON: {
#    "id": "gpt-5.1-codex-max",
#    "object": "model",
#    "created": 1763671532,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-5.1-2025-11-13 at 0x1e1d7cd3c90> JSON: {
#    "id": "gpt-5.1-2025-11-13",
#    "object": "model",
#    "created": 1762800353,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-5.1 at 0x1e1d7cd3330> JSON: {
#    "id": "gpt-5.1",
#    "object": "model",
#    "created": 1762800673,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-5.1-codex at 0x1e1d7cd16c0> JSON: {
#    "id": "gpt-5.1-codex",
#    "object": "model",
#    "created": 1762988221,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-5.1-codex-mini at 0x1e1d7cf8450> JSON: {
#    "id": "gpt-5.1-codex-mini",
#    "object": "model",
# ...

# %%
import pandas as pd
pd.DataFrame(openai.Model.list()['data'])
# Out:
#                         id object     created         owned_by
# 0            gpt-3.5-turbo  model  1677610602           openai
# 1        gpt-5.1-codex-max  model  1763671532           system
# 2       gpt-5.1-2025-11-13  model  1762800353           system
# 3                  gpt-5.1  model  1762800673           system
# 4            gpt-5.1-codex  model  1762988221           system
# ..                     ...    ...         ...              ...
# 74     gpt-5.1-chat-latest  model  1762547951           system
# 75               whisper-1  model  1677532384  openai-internal
# 76                   tts-1  model  1681940951  openai-internal
# 77       gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 78  text-embedding-ada-002  model  1671217299  openai-internal
#
# [79 rows x 4 columns]

# %% [markdown]
# ## Chat Completion API  and Completion API
# * Completion API: Hooks you up with text completions from single prompt
# * Chat Completion API: Nails it in the chat game, keeping the conversational flow intact

# %% [markdown]
# ## ChatCompletion API

# %%
prompt = "Hello , How are you?"

response = openai.ChatCompletion.create(
    model = 'gpt-3.5-turbo',
    messages = [
        {"role": "system","content": "You are a helpful assistant"},
        {"role":"user","content":prompt}
    ]
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 prompt = "Hello , How are you?"
# ----> 3 response = openai.ChatCompletion.create(
#       4     model = 'gpt-3.5-turbo',
#       5     messages = [
#       6         {"role": "system","content": "You are a helpful assistant"},
#       7         {"role":"user","content":prompt}
#       8     ]
#       9 )
#      10 print(response)
#
# File c:\Users\megha\anaconda3\envs\openaidemo\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...
